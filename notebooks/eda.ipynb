# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('processed_data.csv')
df
# Out:
#      Unnamed: 0  coin  symbol         price     1h    24h     7d  \
# 0             0    67      68  40859.460000  0.022  0.030  0.055
# 1             1   148     150   2744.410000  0.024  0.034  0.065
# 2             2   417     445      1.000000 -0.001 -0.001  0.000
# 3             3    45      62    383.430000  0.018  0.028  0.004
# 4             4   439     442      0.999874 -0.001  0.000 -0.000
# ..          ...   ...     ...           ...    ...    ...    ...
# 995         495   205     219      0.055426  0.016 -0.003 -0.088
# 996         496    93      97      0.037961  0.002 -0.012 -0.054
# 997         497     5      31      0.069003 -0.000  0.008 -0.037
# 998         498   401     345      0.464613 -0.003  0.014  0.019
# 999         499   454     455      0.999387  0.053  0.061 -0.122
#
#        24h_volume       mkt_cap        date  liq_ratio
# 0    3.539076e+10  7.709915e+11  2022-03-16   0.045903
# 1    1.974870e+10  3.271044e+11  2022-03-16   0.060374
# ...

# %%
plt.hist(df['liq_ratio'])
plt.show()
